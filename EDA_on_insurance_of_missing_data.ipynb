# %% [markdown]
# # Importing important libraries for EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import random

# %% [markdown]
# # Reading data set

# %%
df= pd.read_csv('insurance.csv')

# %% [markdown]
# # Data Definition
# -age : Age of the policyholder (Numeric)
#
# -sex: Gender of policyholder (Categoric)
#
# -weight: Weight of the policyholder (Numeric)
#
# -bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height, objective index of body weight (kg / m ^ 2) using the ratio of height to weight (Numeric)
#
# -no_of_dependents: Number of dependent persons on the policyholder (Numeric)
#
# -smoker: Indicates policyholder is a smoker or a non-smoker (non-smoker=0;smoker=1) (Categoric)
#
# -claim: The amount claimed by the policyholder (Numeric)
#
# -bloodpressure: Bloodpressure reading of policyholder (Numeric)
#
# -diabetes: Indicates policyholder suffers from diabetes or not (non-diabetic=0; diabetic=1) (Categoric)
#
# -regular_ex: A policyholder regularly excercises or not (no-excercise=0; excercise=1) (Categoric)
#
# -job_title: Job profile of the policyholder (Categoric)
#
# -city: The city in which the policyholder resides (Categoric)
#
# -hereditary_diseases: A policyholder suffering from a hereditary diseases or not (Categoric)

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# 0           0      NewYork             72         0           0
# 1           0       Boston             78         1           1
# 2           1  Phildelphia             88         1           1
# 3           1    Pittsburg             72         1           0
# 4           0      Buffalo             82         1           0
# ...       ...          ...            ...       ...         ...
# 14995       1     Florence             54         1           0
# 14996       0        Miami             64         1           0
# 14997       0        Tampa             52         1           0
# 14998       0   PanamaCity             70         1           0
# 14999       0    Kingsport             72         1           0
#
#              job_title    claim
# 0                Actor  13112.6
# 1             Engineer   9567.0
# 2          Academician  32734.2
# 3                 Chef  48517.6
# 4           HomeMakers   1731.7
# ...                ...      ...
# 14995        FilmMaker  21082.2
# 14996          Student   7512.3
# 14997  FashionDesigner   1391.5
# 14998           Farmer   9144.6
# 14999          Manager  25992.8
#
# [15000 rows x 13 columns]

# %% [markdown]
# # Top 5 rows of dataframe

# %%
df.head()
# Out:
#     age     sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 0  60.0    male      64  24.3           NoDisease                 1       0
# 1  49.0  female      75  22.6           NoDisease                 1       0
# 2  32.0  female      64  17.8            Epilepsy                 2       1
# 3  61.0  female      53  36.4           NoDisease                 1       1
# 4  19.0  female      50  20.6           NoDisease                 0       0
#
#           city  bloodpressure  diabetes  regular_ex    job_title    claim
# 0      NewYork             72         0           0        Actor  13112.6
# 1       Boston             78         1           1     Engineer   9567.0
# 2  Phildelphia             88         1           1  Academician  32734.2
# 3    Pittsburg             72         1           0         Chef  48517.6
# 4      Buffalo             82         1           0   HomeMakers   1731.7

# %% [markdown]
# # bottom 5 rows of dataframe

# %%
df.tail()
# Out:
#         age   sex  weight   bmi hereditary_diseases  no_of_dependents  smoker  \
# 14995  39.0  male      49  28.3           NoDisease                 1       1
# 14996  39.0  male      74  29.6           NoDisease                 4       0
# 14997  20.0  male      62  33.3           NoDisease                 0       0
# 14998  52.0  male      88  36.7           NoDisease                 0       0
# 14999  52.0  male      57  26.4           NoDisease                 3       0
#
#              city  bloodpressure  diabetes  regular_ex        job_title  \
# 14995    Florence             54         1           0        FilmMaker
# 14996       Miami             64         1           0          Student
# 14997       Tampa             52         1           0  FashionDesigner
# 14998  PanamaCity             70         1           0           Farmer
# 14999   Kingsport             72         1           0          Manager
#
#          claim
# 14995  21082.2
# 14996   7512.3
# 14997   1391.5
# 14998   9144.6
# 14999  25992.8

# %% [markdown]
# # Shape of dataframe

# %%
df.shape
# Out:
# (15000, 13)

# %%
print(f"No of rows: {df.shape[0]}\nNo of columns: {df.shape[1]}")
# Out:
# No of rows: 15000
# No of columns: 13

# %% [markdown]
# # Checking datatypes of each feature

# %%
df.dtypes
# Out:
# age                    float64
# sex                     object
# weight                   int64
# bmi                    float64
# hereditary_diseases     object
# no_of_dependents         int64
# smoker                   int64
# city                    object
# bloodpressure            int64
# diabetes                 int64
# regular_ex               int64
# job_title               object
# claim                  float64
# dtype: object

# %% [markdown]
# # converting numerical columns into categorical

# %%
df['smoker'].replace({0:'no',1:'yes'},inplace=True)

# %%
df['regular_ex'].replace({0:'no',1:'yes'},inplace=True)

# %%
df['diabetes'].replace({0:'no',1:'yes'},inplace=True)

# %%
tot=df.shape[0]

# %%
tot
# Out:
# 15000

# %% [markdown]
# # checking null values

# %%
df.isnull().sum()
# Out:
# age                    396
# sex                      0
# weight                   0
# bmi                    956
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
round((df.isnull().sum())/tot)*100
# Out:
# age                    0.0
# sex                    0.0
# weight                 0.0
# bmi                    0.0
# hereditary_diseases    0.0
# no_of_dependents       0.0
# smoker                 0.0
# city                   0.0
# bloodpressure          0.0
# diabetes               0.0
# regular_ex             0.0
# job_title              0.0
# claim                  0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  14604 non-null  float64
#  1   sex                  15000 non-null  object
#  2   weight               15000 non-null  int64
#  3   bmi                  14044 non-null  float64
#  4   hereditary_diseases  15000 non-null  object
#  5   no_of_dependents     15000 non-null  int64
#  6   smoker               15000 non-null  object
#  7   city                 15000 non-null  object
#  8   bloodpressure        15000 non-null  int64
#  9   diabetes             15000 non-null  object
#  10  regular_ex           15000 non-null  object
#  11  job_title            15000 non-null  object
#  12  claim                15000 non-null  float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# # Statistical description of numerical features

# %%
df.describe()
# Out:
#                 age        weight           bmi  no_of_dependents  \
# count  14604.000000  15000.000000  14044.000000      15000.000000
# mean      39.547521     64.909600     30.266413          1.129733
# std       14.015966     13.701935      6.122950          1.228469
# min       18.000000     34.000000     16.000000          0.000000
# 25%       27.000000     54.000000     25.700000          0.000000
# 50%       40.000000     63.000000     29.400000          1.000000
# 75%       52.000000     76.000000     34.400000          2.000000
# max       64.000000     95.000000     53.100000          5.000000
#
#        bloodpressure         claim
# count   15000.000000  15000.000000
# mean       68.650133  13401.437620
# std        19.418515  12148.239619
# min         0.000000   1121.900000
# 25%        64.000000   4846.900000
# 50%        71.000000   9545.650000
# 75%        80.000000  16519.125000
# max       122.000000  63770.400000

# %% [markdown]
# # Statistical description of Categorical features

# %%
df.describe(exclude='number')
# Out:
#            sex hereditary_diseases smoker        city diabetes regular_ex  \
# count    15000               15000  15000       15000    15000      15000
# unique       2                  10      2          91        2          2
# top     female           NoDisease     no  NewOrleans      yes         no
# freq      7652               13998  12028         302    11655      11638
#
#        job_title
# count      15000
# unique        35
# top      Student
# freq        1320

# %% [markdown]
# # checking duplicate values

# %%
df[df.duplicated()]
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 605    46.0  female      68   NaN           NoDisease                 2
# 608    27.0  female      82   NaN           NoDisease                 3
# 898    48.0  female      67  33.1           Alzheimer                 0
# 919    26.0    male      56  23.7           NoDisease                 2
# 970    48.0  female      70  28.9           NoDisease                 1
# ...     ...     ...     ...   ...                 ...               ...
# 14966  46.0    male      46  22.3           NoDisease                 0
# 14971  18.0  female      53  27.3           NoDisease                 3
# 14987  47.0    male      94  47.5           NoDisease                 1
# 14989  44.0    male      90  38.1           NoDisease                 1
# 14997  20.0    male      62  33.3           NoDisease                 0
#
#       smoker        city  bloodpressure diabetes regular_ex        job_title  \
# 605       no  LosAngeles             60      yes         no           Dancer
# 608       no   Oceanside             82      yes        yes        Architect
# 898      yes  Cincinnati             70      yes         no   ITProfessional
# 919       no     Kingman             72      yes         no       HomeMakers
# 970       no   KanasCity             72       no         no        Architect
# ...      ...         ...            ...      ...        ...              ...
# 14966     no  Louisville             72      yes         no      Academician
# 14971    yes      Boston             85      yes         no          Student
# 14987     no     Raleigh             61      yes         no      Academician
# 14989     no     Georgia             76      yes         no         Engineer
# 14997     no       Tampa             52      yes         no  FashionDesigner
#
#          claim
# 605     8825.1
# 608    18804.8
# 898    40974.2
# 919     3484.3
# 970     9249.5
# ...        ...
# 14966   7147.1
# 14971  18223.5
# 14987   8083.9
# 14989   7152.7
# 14997   1391.5
#
# [1096 rows x 13 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14994  38.0  female      71  27.3           NoDisease                 1
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#       smoker         city  bloodpressure diabetes regular_ex    job_title  \
# 0         no      NewYork             72       no         no        Actor
# 1         no       Boston             78      yes        yes     Engineer
# 2        yes  Phildelphia             88      yes        yes  Academician
# 3        yes    Pittsburg             72      yes         no         Chef
# 4         no      Buffalo             82      yes         no   HomeMakers
# ...      ...          ...            ...      ...        ...          ...
# 14994     no    Knoxville              0      yes         no         Chef
# 14995    yes     Florence             54      yes         no    FilmMaker
# 14996     no        Miami             64      yes         no      Student
# 14998     no   PanamaCity             70      yes         no       Farmer
# 14999     no    Kingsport             72      yes         no      Manager
#
#          claim
# 0      13112.6
# 1       9567.0
# 2      32734.2
# 3      48517.6
# 4       1731.7
# ...        ...
# 14994   6555.1
# 14995  21082.2
# 14996   7512.3
# 14998   9144.6
# 14999  25992.8
#
# [13904 rows x 13 columns]

# %% [markdown]
# # Display all columns name

# %%
df.columns
# Out:
# Index(['age', 'sex', 'weight', 'bmi', 'hereditary_diseases',
#        'no_of_dependents', 'smoker', 'city', 'bloodpressure', 'diabetes',
#        'regular_ex', 'job_title', 'claim'],
#       dtype='object')

# %% [markdown]
# # Numerical and categorical columns segregation

# %%
num_col=df.select_dtypes(include='number').columns.to_list()
cat_col=df.select_dtypes(exclude='number').columns.to_list()

# %%
cat_col
# Out:
# ['sex',
#  'hereditary_diseases',
#  'smoker',
#  'city',
#  'diabetes',
#  'regular_ex',
#  'job_title']

# %%
df['hereditary_diseases'].value_counts()
# Out:
# NoDisease       12965
# Alzheimer         137
# Diabetes          136
# Obesity           130
# EyeDisease        112
# Cancer            107
# Arthritis          88
# HeartDisease       87
# Epilepsy           77
# High BP            65
# Name: hereditary_diseases, dtype: int64

# %%
num_col
# Out:
# ['age', 'weight', 'bmi', 'no_of_dependents', 'bloodpressure', 'claim']

# %%
cat_col=[]
for col in df.columns:
    if df[col].dtypes=='O':
        cat_col.append(col)

# %%
cat_col
# Out:
# ['sex',
#  'hereditary_diseases',
#  'smoker',
#  'city',
#  'diabetes',
#  'regular_ex',
#  'job_title']

# %%
num_col=[]
for col in df.columns:
    if df[col].dtypes!='O':
        num_col.append(col)

# %%
num_col
# Out:
# ['age', 'weight', 'bmi', 'no_of_dependents', 'bloodpressure', 'claim']

# %%
#cat_col=[]
#for col in df.columns:
 #   if df[col].dtypes=='O':
  #      cat_col.append(col)

# %%
#cat_col.append('smoker')

# %%
#cat_col.remove('hereditary_diseases')

# %%
#cat_col.remove('city')

# %%
#cat_col.remove('job_title')

# %%
#cat_col.append('regular_ex')

# %%
sns.set_style("darkgrid", {"grid.color": ".9", "grid.linestyle": "-"})

# %% [markdown]
# # univariate analysis

# %%
#categorical data

# %%
cat_col=df.select_dtypes(exclude='number').columns.to_list()

# %%
df['sex'].value_counts()
# Out:
# female    7091
# male      6813
# Name: sex, dtype: int64

# %%
for col in cat_col:
    print(df[col].value_counts(),"\n\n")
# Out:
# female    7091
# male      6813
# Name: sex, dtype: int64
#
#
# NoDisease       12965
# Alzheimer         137
# Diabetes          136
# Obesity           130
# EyeDisease        112
# Cancer            107
# Arthritis          88
# HeartDisease       87
# Epilepsy           77
# High BP            65
# Name: hereditary_diseases, dtype: int64
#
#
# no     11114
# yes     2790
# Name: smoker, dtype: int64
#
#
# Nashville     270
# Memphis       269
# NewOrleans    268
# Charleston    267
# Brimingham    266
#              ...
# York           68
# Warwick        67
# Syracuse       67
# Baltimore      67
# Trenton        66
# Name: city, Length: 91, dtype: int64
#
#
# yes    10722
# no      3182
# Name: diabetes, dtype: int64
#
#
# no     10696
# yes     3208
# Name: regular_ex, dtype: int64
#
#
# Student              1220
# HomeMakers            899
# Singer                697
# FilmMaker             675
# Actor                 662
# Dancer                645
# HouseKeeper           622
# Manager               565
# Police                381
# Photographer          370
# Beautician            363
# Engineer              346
# FashionDesigner       346
# Clerks                345
# Accountant            345
# CEO                   344
# Architect             337
# Politician            333
# ITProfessional        326
# DataScientist         304
# Lawyer                289
# Academician           287
# Doctor                283
# DefencePersonnels     266
# Blogger               262
# Chef                  257
# Journalist            255
# FilmDirector          255
# Technician            253
# CA                    250
# Analyst               239
# Farmer                235
# GovEmployee           232
# Buisnessman           224
# Labourer              192
# Name: job_title, dtype: int64

# %%
cat_col
# Out:
# ['sex',
#  'hereditary_diseases',
#  'smoker',
#  'city',
#  'diabetes',
#  'regular_ex',
#  'job_title']

# %% [markdown]
# # Countplot of all categorical columns

# %%
for col in cat_col:
    plt.figure(figsize=(5,5))
    ax=sns.countplot(x=col,data=df)
    for x in ax.containers:
        ax.bar_label(x)
    
    plt.show()

# %%
for col in cat_col:
    plt.figure(figsize=(5,5))
    ax=sns.countplot(x=col,data=df)
    for x in ax.containers:
        ax.bar_label(x)
    
    plt.show()

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='sex'>

# %%
plt.pie(x=df['sex'].value_counts(),autopct='%.2f')
plt.show()

# %%
df['smoker'].value_counts().plot(kind='pie',autopct="%.f")
# Out:
# <Axes: ylabel='smoker'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13904 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  13543 non-null  float64
#  1   sex                  13904 non-null  object
#  2   weight               13904 non-null  int64
#  3   bmi                  13003 non-null  float64
#  4   hereditary_diseases  13904 non-null  object
#  5   no_of_dependents     13904 non-null  int64
#  6   smoker               13904 non-null  object
#  7   city                 13904 non-null  object
#  8   bloodpressure        13904 non-null  int64
#  9   diabetes             13904 non-null  object
#  10  regular_ex           13904 non-null  object
#  11  job_title            13904 non-null  object
#  12  claim                13904 non-null  float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.5+ MB

# %%
numerical=['age','bmi','no_of_dependents']

# %%
df[numerical]
# Out:
#         age   bmi  no_of_dependents
# 0      60.0  24.3                 1
# 1      49.0  22.6                 1
# 2      32.0  17.8                 2
# 3      61.0  36.4                 1
# 4      19.0  20.6                 0
# ...     ...   ...               ...
# 14994  38.0  27.3                 1
# 14995  39.0  28.3                 1
# 14996  39.0  29.6                 4
# 14998  52.0  36.7                 0
# 14999  52.0  26.4                 3
#
# [13904 rows x 3 columns]

# %%
fig,axs=plt.subplots(1,2,figsize=(10,6))
sns.histplot(df['age'],kde=True,ax=axs[0])
sns.kdeplot(df['age'],ax=axs[1])
print('skewness:',df['age'].skew())
# Out:
# skewness: 0.006109185887158953

# %%
for col in numerical:
    fig,axs=plt.subplots(1,2,figsize=(10,6))
    sns.histplot(df[col],kde=True,ax=axs[0])
    sns.kdeplot(df[col],ax=axs[1])
    print('skewness:',df[col].skew())
# Out:
# skewness: 0.006109185887158953
# skewness: 0.3774683179762625
# skewness: 0.9315683898573424

# %% [markdown]
# # box plot for outlier detection

# %%
for col in numerical:
    plt.figure(figsize=(8,4))
    sns.boxplot(df,x=col)

# %% [markdown]
# # bivarients /multivarients

# %%
sns.scatterplot(df,x='age',y='bmi',hue='sex',size='no_of_dependents')
plt.show()

# %%
sns.boxplot(x='sex',y='age',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.scatterplot(df,x='smoker',y='bmi')
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
sns.boxplot(x='smoker',y='bmi',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='bmi'>

# %%
ax=sns.barplot(df,x='smoker',y='age',hue='sex')
for x in ax.containers:
    print(ax.bar_label(x))
# Out:
# [Text(0, 0, '39.9282'), Text(0, 0, '38.8788')]
# [Text(0, 0, '39.5152'), Text(0, 0, '39.0304')]

# %%
df=pd.read_csv('insurances.csv')

# %%
df
# Out:
#       index  age     sex     bmi  children smoker     region      charges
# 0         0   19  female  27.900         0    yes  southwest  16884.92400
# 1         1   18    male  33.770         1     no  southeast   1725.55230
# 2         2   28    male  33.000         3     no  southeast   4449.46200
# 3         3   33    male  22.705         0     no  northwest  21984.47061
# 4         4   32    male  28.880         0     no  northwest   3866.85520
# ...     ...  ...     ...     ...       ...    ...        ...          ...
# 1333   1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 8 columns]

# %%
sns.countplot(data=df,x='region',hue='sex')
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %% [raw]
# obe=balance data set

# %%
plt.figure(figsize=(6,6))
ax=sns.countplot(data=df,x='region',hue='sex')
for x in ax.containers:
    ax.bar_label(x)
plt.show()

# %% [markdown]
# # missing data handling

# %%
df= pd.read_csv('insurance.csv')

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# 0           0      NewYork             72         0           0
# 1           0       Boston             78         1           1
# 2           1  Phildelphia             88         1           1
# 3           1    Pittsburg             72         1           0
# 4           0      Buffalo             82         1           0
# ...       ...          ...            ...       ...         ...
# 14995       1     Florence             54         1           0
# 14996       0        Miami             64         1           0
# 14997       0        Tampa             52         1           0
# 14998       0   PanamaCity             70         1           0
# 14999       0    Kingsport             72         1           0
#
#              job_title    claim
# 0                Actor  13112.6
# 1             Engineer   9567.0
# 2          Academician  32734.2
# 3                 Chef  48517.6
# 4           HomeMakers   1731.7
# ...                ...      ...
# 14995        FilmMaker  21082.2
# 14996          Student   7512.3
# 14997  FashionDesigner   1391.5
# 14998           Farmer   9144.6
# 14999          Manager  25992.8
#
# [15000 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# age                    396
# sex                      0
# weight                   0
# bmi                    956
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %% [raw]
# #method1: dropna()
# - no of rows have very less percentage of total

# %%
df.shape
# Out:
# (15000, 13)

# %%
df.dropna()
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# 0           0      NewYork             72         0           0
# 1           0       Boston             78         1           1
# 2           1  Phildelphia             88         1           1
# 3           1    Pittsburg             72         1           0
# 4           0      Buffalo             82         1           0
# ...       ...          ...            ...       ...         ...
# 14995       1     Florence             54         1           0
# 14996       0        Miami             64         1           0
# 14997       0        Tampa             52         1           0
# 14998       0   PanamaCity             70         1           0
# 14999       0    Kingsport             72         1           0
#
#              job_title    claim
# 0                Actor  13112.6
# 1             Engineer   9567.0
# 2          Academician  32734.2
# 3                 Chef  48517.6
# 4           HomeMakers   1731.7
# ...                ...      ...
# 14995        FilmMaker  21082.2
# 14996          Student   7512.3
# 14997  FashionDesigner   1391.5
# 14998           Farmer   9144.6
# 14999          Manager  25992.8
#
# [13648 rows x 13 columns]

# %% [markdown]
# # method2:iputing the null value with mean

# %%
i_age=list(df[df[('age')].isnull()==True].index)

# %%
df.loc[i_age]
# Out:
#        age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 76     NaN  female      88  29.6           NoDisease                 1
# 82     NaN  female      64  24.6           NoDisease                 2
# 105    NaN  female      73  20.2           NoDisease                 2
# 106    NaN  female      71  21.8           NoDisease                 1
# 110    NaN  female      70  34.3           NoDisease                 5
# ...    ...     ...     ...   ...                 ...               ...
# 14769  NaN  female      55  24.2           NoDisease                 5
# 14882  NaN  female      62  25.6           NoDisease                 4
# 14943  NaN    male      68  27.9           NoDisease                 0
# 14962  NaN    male      47  29.0           NoDisease                 1
# 14969  NaN    male      47  29.0           NoDisease                 1
#
#        smoker        city  bloodpressure  diabetes  regular_ex      job_title  \
# 76          0    Montrose             78         0           0         Singer
# 82          0     SanLuis             70         0           1  DataScientist
# 105         0     Raleigh             74         0           0            CEO
# 106         1     Houston             84         1           0         Singer
# 110         0  LosAngeles             82         1           0        Analyst
# ...       ...         ...            ...       ...         ...            ...
# 14769       0     Newport             90         1           0    Buisnessman
# 14882       0       Miami             70         0           1         Doctor
# 14943       0      Fresno             58         0           0      Architect
# 14962       0     Atlanta             86         1           0    Academician
# 14969       0  NewOrleans             86         1           0    Academician
#
#          claim
# 76      3947.4
# 82      4529.5
# 105     4906.4
# 106    16657.7
# 110     8596.8
# ...        ...
# 14769   8965.8
# 14882   5708.9
# 14943   2867.1
# 14962   4040.6
# 14969   4040.6
#
# [396 rows x 13 columns]

# %%
df['age'].fillna(value=df['age'].mean(),inplace=True)

# %% [markdown]
# # simple importing

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'

# %%
from sklearn.impute import SimpleImputer

# %%
num_col=df.select_dtypes(include='number').columns.to_list()

# %%
imp=SimpleImputer(strategy='mean')

# %%
df_mean=imp.fit_transform(df[num_col])

# %%
df_mean
# Out:
# array([[6.00000e+01, 6.40000e+01, 2.43000e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.31126e+04],
#        [4.90000e+01, 7.50000e+01, 2.26000e+01, ..., 1.00000e+00,
#         1.00000e+00, 9.56700e+03],
#        [3.20000e+01, 6.40000e+01, 1.78000e+01, ..., 1.00000e+00,
#         1.00000e+00, 3.27342e+04],
#        ...,
#        [2.00000e+01, 6.20000e+01, 3.33000e+01, ..., 1.00000e+00,
#         0.00000e+00, 1.39150e+03],
#        [5.20000e+01, 8.80000e+01, 3.67000e+01, ..., 1.00000e+00,
#         0.00000e+00, 9.14460e+03],
#        [5.20000e+01, 5.70000e+01, 2.64000e+01, ..., 1.00000e+00,
#         0.00000e+00, 2.59928e+04]])

# %%
imp.feature_names_in_
# Out:
# array(['age', 'weight', 'bmi', 'no_of_dependents', 'smoker',
#        'bloodpressure', 'diabetes', 'regular_ex', 'claim'], dtype=object)

# %%
df_mean=pd.DataFrame(df_mean,columns=imp.feature_names_in_)

# %%
df_mean
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 14995  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 14996  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 14997  20.0    62.0  33.3               0.0     0.0           52.0       1.0
# 14998  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 14999  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# 0             0.0  13112.6
# 1             1.0   9567.0
# 2             1.0  32734.2
# 3             0.0  48517.6
# 4             0.0   1731.7
# ...           ...      ...
# 14995         0.0  21082.2
# 14996         0.0   7512.3
# 14997         0.0   1391.5
# 14998         0.0   9144.6
# 14999         0.0  25992.8
#
# [15000 rows x 9 columns]

# %%
for col in num_col:
    fig,axs=plt.subplots(1,2,figsize=(10,6))
    sns.histplot(df_mean,kde=True,ax=axs[0])
    sns.kdeplot(df[col],ax=axs[1])
    print('skewness:',df[col].skew())
# Out:
# KeyboardInterrupt
# Error in callback <function _draw_all_if_interactive at 0x000002558A1DBF60> (for post_execute):
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x000002558C98FC40> (for post_execute):
# KeyboardInterrupt

# %%
for col in numerical:
    fig,axs=plt.subplots(1,2,figsize=(10,6))
    sns.histplot(df[col],kde=True,ax=axs[0])
    sns.kdeplot(df[col],ax=axs[1])
    print('skewness:',df[col].skew())

# %%
imp_median=SimpleImputer(strategy='median')

# %%
df_median=imp_median.fit_transform(df[num_col])

# %%
df_median
# Out:
# array([[6.00000e+01, 6.40000e+01, 2.43000e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.31126e+04],
#        [4.90000e+01, 7.50000e+01, 2.26000e+01, ..., 1.00000e+00,
#         1.00000e+00, 9.56700e+03],
#        [3.20000e+01, 6.40000e+01, 1.78000e+01, ..., 1.00000e+00,
#         1.00000e+00, 3.27342e+04],
#        ...,
#        [2.00000e+01, 6.20000e+01, 3.33000e+01, ..., 1.00000e+00,
#         0.00000e+00, 1.39150e+03],
#        [5.20000e+01, 8.80000e+01, 3.67000e+01, ..., 1.00000e+00,
#         0.00000e+00, 9.14460e+03],
#        [5.20000e+01, 5.70000e+01, 2.64000e+01, ..., 1.00000e+00,
#         0.00000e+00, 2.59928e+04]])

# %%
df_medain=pd.DataFrame(df_median,columns=imp_median.feature_names_in_)

# %%
df_medain
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 14995  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 14996  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 14997  20.0    62.0  33.3               0.0     0.0           52.0       1.0
# 14998  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 14999  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# 0             0.0  13112.6
# 1             1.0   9567.0
# 2             1.0  32734.2
# 3             0.0  48517.6
# 4             0.0   1731.7
# ...           ...      ...
# 14995         0.0  21082.2
# 14996         0.0   7512.3
# 14997         0.0   1391.5
# 14998         0.0   9144.6
# 14999         0.0  25992.8
#
# [15000 rows x 9 columns]

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# 0           0      NewYork             72         0           0
# 1           0       Boston             78         1           1
# 2           1  Phildelphia             88         1           1
# 3           1    Pittsburg             72         1           0
# 4           0      Buffalo             82         1           0
# ...       ...          ...            ...       ...         ...
# 14995       1     Florence             54         1           0
# 14996       0        Miami             64         1           0
# 14997       0        Tampa             52         1           0
# 14998       0   PanamaCity             70         1           0
# 14999       0    Kingsport             72         1           0
#
#              job_title    claim
# 0                Actor  13112.6
# 1             Engineer   9567.0
# 2          Academician  32734.2
# 3                 Chef  48517.6
# 4           HomeMakers   1731.7
# ...                ...      ...
# 14995        FilmMaker  21082.2
# 14996          Student   7512.3
# 14997  FashionDesigner   1391.5
# 14998           Farmer   9144.6
# 14999          Manager  25992.8
#
# [15000 rows x 13 columns]

# %%
df_mean
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 14995  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 14996  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 14997  20.0    62.0  33.3               0.0     0.0           52.0       1.0
# 14998  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 14999  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# 0             0.0  13112.6
# 1             1.0   9567.0
# 2             1.0  32734.2
# 3             0.0  48517.6
# 4             0.0   1731.7
# ...           ...      ...
# 14995         0.0  21082.2
# 14996         0.0   7512.3
# 14997         0.0   1391.5
# 14998         0.0   9144.6
# 14999         0.0  25992.8
#
# [15000 rows x 9 columns]

# %%
df_medain
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 14995  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 14996  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 14997  20.0    62.0  33.3               0.0     0.0           52.0       1.0
# 14998  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 14999  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# 0             0.0  13112.6
# 1             1.0   9567.0
# 2             1.0  32734.2
# 3             0.0  48517.6
# 4             0.0   1731.7
# ...           ...      ...
# 14995         0.0  21082.2
# 14996         0.0   7512.3
# 14997         0.0   1391.5
# 14998         0.0   9144.6
# 14999         0.0  25992.8
#
# [15000 rows x 9 columns]

# %%
df['imputed_age']=df_mean['age']
df['imputed_bmi']=df_mean['bmi']

# %%
df.isnull().sum()
# Out:
# age                      0
# sex                      0
# weight                   0
# bmi                    956
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# imputed_age              0
# imputed_bmi              0
# dtype: int64

# %%
df_mean.isnull().sum()
# Out:
# age                 0
# weight              0
# bmi                 0
# no_of_dependents    0
# smoker              0
# bloodpressure       0
# diabetes            0
# regular_ex          0
# claim               0
# dtype: int64

# %%
df_medain.isnull().sum()
# Out:
# age                 0
# weight              0
# bmi                 0
# no_of_dependents    0
# smoker              0
# bloodpressure       0
# diabetes            0
# regular_ex          0
# claim               0
# dtype: int64

# %%
sns.kdeplot(df['bmi'],color='b')
sns.kdeplot(df['imputed_bmi'],color='g')
plt.show()

# %%
df['smoker'].replace({0:'no',1:'yes'},inplace=True)
df['diabetes'].replace({0:'no',1:'yes'},inplace=True)
df['regular_ex'].replace({0:'no',1:'yes'},inplace=True)

# %%
cat_col=df.select_dtypes(exclude='number').columns.to_list()

# %% [markdown]
# # multivarient imputation of missing value

# %% [markdown]
# # itetrative imputer

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
i_impute=IterativeImputer()

# %%
num_col=df.select_dtypes(include='number').columns.to_list()

# %%
df_it=i_impute.fit_transform(df[num_col])

# %%
df_it
# Out:
# array([[6.00000e+01, 6.40000e+01, 2.43000e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.31126e+04],
#        [4.90000e+01, 7.50000e+01, 2.26000e+01, ..., 1.00000e+00,
#         1.00000e+00, 9.56700e+03],
#        [3.20000e+01, 6.40000e+01, 1.78000e+01, ..., 1.00000e+00,
#         1.00000e+00, 3.27342e+04],
#        ...,
#        [2.00000e+01, 6.20000e+01, 3.33000e+01, ..., 1.00000e+00,
#         0.00000e+00, 1.39150e+03],
#        [5.20000e+01, 8.80000e+01, 3.67000e+01, ..., 1.00000e+00,
#         0.00000e+00, 9.14460e+03],
#        [5.20000e+01, 5.70000e+01, 2.64000e+01, ..., 1.00000e+00,
#         0.00000e+00, 2.59928e+04]])

# %%
df.isnull().sum()
# Out:
# age                    396
# sex                      0
# weight                   0
# bmi                    956
# hereditary_diseases      0
# no_of_dependents         0
# smoker                   0
# city                     0
# bloodpressure            0
# diabetes                 0
# regular_ex               0
# job_title                0
# claim                    0
# dtype: int64

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# 0           0      NewYork             72         0           0
# 1           0       Boston             78         1           1
# 2           1  Phildelphia             88         1           1
# 3           1    Pittsburg             72         1           0
# 4           0      Buffalo             82         1           0
# ...       ...          ...            ...       ...         ...
# 14995       1     Florence             54         1           0
# 14996       0        Miami             64         1           0
# 14997       0        Tampa             52         1           0
# 14998       0   PanamaCity             70         1           0
# 14999       0    Kingsport             72         1           0
#
#              job_title    claim
# 0                Actor  13112.6
# 1             Engineer   9567.0
# 2          Academician  32734.2
# 3                 Chef  48517.6
# 4           HomeMakers   1731.7
# ...                ...      ...
# 14995        FilmMaker  21082.2
# 14996          Student   7512.3
# 14997  FashionDesigner   1391.5
# 14998           Farmer   9144.6
# 14999          Manager  25992.8
#
# [15000 rows x 13 columns]

# %%
df_it=pd.DataFrame(df_it,columns=num_col)

# %%
df_it.isnull().sum()
# Out:
# age                 0
# weight              0
# bmi                 0
# no_of_dependents    0
# smoker              0
# bloodpressure       0
# diabetes            0
# regular_ex          0
# claim               0
# dtype: int64

# %%
df_it.shape
# Out:
# (15000, 9)

# %%
df_it
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 14995  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 14996  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 14997  20.0    62.0  33.3               0.0     0.0           52.0       1.0
# 14998  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 14999  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# 0             0.0  13112.6
# 1             1.0   9567.0
# 2             1.0  32734.2
# 3             0.0  48517.6
# 4             0.0   1731.7
# ...           ...      ...
# 14995         0.0  21082.2
# 14996         0.0   7512.3
# 14997         0.0   1391.5
# 14998         0.0   9144.6
# 14999         0.0  25992.8
#
# [15000 rows x 9 columns]

# %%
df['age_it']=df_it['age']

# %%
df['bmi_it']=df_it['bmi']

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# 0           0      NewYork             72         0           0
# 1           0       Boston             78         1           1
# 2           1  Phildelphia             88         1           1
# 3           1    Pittsburg             72         1           0
# 4           0      Buffalo             82         1           0
# ...       ...          ...            ...       ...         ...
# 14995       1     Florence             54         1           0
# 14996       0        Miami             64         1           0
# 14997       0        Tampa             52         1           0
# 14998       0   PanamaCity             70         1           0
# 14999       0    Kingsport             72         1           0
#
#              job_title    claim  age_it
# 0                Actor  13112.6    60.0
# 1             Engineer   9567.0    49.0
# 2          Academician  32734.2    32.0
# 3                 Chef  48517.6    61.0
# 4           HomeMakers   1731.7    19.0
# ...                ...      ...     ...
# 14995        FilmMaker  21082.2    39.0
# 14996          Student   7512.3    39.0
# 14997  FashionDesigner   1391.5    20.0
# 14998           Farmer   9144.6    52.0
# 14999          Manager  25992.8    52.0
#
# [15000 rows x 14 columns]

# %%
sns.kdeplot(df['bmi'],color='b')
sns.kdeplot(df['bmi_it'],color='g')
plt.show()

# %%
sns.kdeplot(df['age'],color='b')
sns.kdeplot(df['age_it'],color='g')
plt.show()

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# 0           0      NewYork             72         0           0
# 1           0       Boston             78         1           1
# 2           1  Phildelphia             88         1           1
# 3           1    Pittsburg             72         1           0
# 4           0      Buffalo             82         1           0
# ...       ...          ...            ...       ...         ...
# 14995       1     Florence             54         1           0
# 14996       0        Miami             64         1           0
# 14997       0        Tampa             52         1           0
# 14998       0   PanamaCity             70         1           0
# 14999       0    Kingsport             72         1           0
#
#              job_title    claim  age_it  bmi_it
# 0                Actor  13112.6    60.0    24.3
# 1             Engineer   9567.0    49.0    22.6
# 2          Academician  32734.2    32.0    17.8
# 3                 Chef  48517.6    61.0    36.4
# 4           HomeMakers   1731.7    19.0    20.6
# ...                ...      ...     ...     ...
# 14995        FilmMaker  21082.2    39.0    28.3
# 14996          Student   7512.3    39.0    29.6
# 14997  FashionDesigner   1391.5    20.0    33.3
# 14998           Farmer   9144.6    52.0    36.7
# 14999          Manager  25992.8    52.0    26.4
#
# [15000 rows x 15 columns]

# %%
df= pd.read_csv('insurance.csv')

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14997  20.0    male      62  33.3           NoDisease                 0
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex  \
# 0           0      NewYork             72         0           0
# 1           0       Boston             78         1           1
# 2           1  Phildelphia             88         1           1
# 3           1    Pittsburg             72         1           0
# 4           0      Buffalo             82         1           0
# ...       ...          ...            ...       ...         ...
# 14995       1     Florence             54         1           0
# 14996       0        Miami             64         1           0
# 14997       0        Tampa             52         1           0
# 14998       0   PanamaCity             70         1           0
# 14999       0    Kingsport             72         1           0
#
#              job_title    claim
# 0                Actor  13112.6
# 1             Engineer   9567.0
# 2          Academician  32734.2
# 3                 Chef  48517.6
# 4           HomeMakers   1731.7
# ...                ...      ...
# 14995        FilmMaker  21082.2
# 14996          Student   7512.3
# 14997  FashionDesigner   1391.5
# 14998           Farmer   9144.6
# 14999          Manager  25992.8
#
# [15000 rows x 13 columns]

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14994  38.0  female      71  27.3           NoDisease                 1
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex    job_title  \
# 0           0      NewYork             72         0           0        Actor
# 1           0       Boston             78         1           1     Engineer
# 2           1  Phildelphia             88         1           1  Academician
# 3           1    Pittsburg             72         1           0         Chef
# 4           0      Buffalo             82         1           0   HomeMakers
# ...       ...          ...            ...       ...         ...          ...
# 14994       0    Knoxville              0         1           0         Chef
# 14995       1     Florence             54         1           0    FilmMaker
# 14996       0        Miami             64         1           0      Student
# 14998       0   PanamaCity             70         1           0       Farmer
# 14999       0    Kingsport             72         1           0      Manager
#
#          claim
# 0      13112.6
# 1       9567.0
# 2      32734.2
# 3      48517.6
# 4       1731.7
# ...        ...
# 14994   6555.1
# 14995  21082.2
# 14996   7512.3
# 14998   9144.6
# 14999  25992.8
#
# [13904 rows x 13 columns]

# %% [markdown]
# # knn imputer

# %%
from sklearn.impute import KNNImputer

# %%
knn_imp=KNNImputer()

# %%
arr_knn=knn_imp.fit_transform(df[num_col])

# %%
df_knn=pd.DataFrame(arr_knn,columns=num_col)

# %%
df_knn
# Out:
#         age  weight   bmi  no_of_dependents  smoker  bloodpressure  diabetes  \
# 0      60.0    64.0  24.3               1.0     0.0           72.0       0.0
# 1      49.0    75.0  22.6               1.0     0.0           78.0       1.0
# 2      32.0    64.0  17.8               2.0     1.0           88.0       1.0
# 3      61.0    53.0  36.4               1.0     1.0           72.0       1.0
# 4      19.0    50.0  20.6               0.0     0.0           82.0       1.0
# ...     ...     ...   ...               ...     ...            ...       ...
# 14995  39.0    49.0  28.3               1.0     1.0           54.0       1.0
# 14996  39.0    74.0  29.6               4.0     0.0           64.0       1.0
# 14997  20.0    62.0  33.3               0.0     0.0           52.0       1.0
# 14998  52.0    88.0  36.7               0.0     0.0           70.0       1.0
# 14999  52.0    57.0  26.4               3.0     0.0           72.0       1.0
#
#        regular_ex    claim
# 0             0.0  13112.6
# 1             1.0   9567.0
# 2             1.0  32734.2
# 3             0.0  48517.6
# 4             0.0   1731.7
# ...           ...      ...
# 14995         0.0  21082.2
# 14996         0.0   7512.3
# 14997         0.0   1391.5
# 14998         0.0   9144.6
# 14999         0.0  25992.8
#
# [15000 rows x 9 columns]

# %%
df['age_knn']=df_knn['age']

# %%
df['bmi_knn']=df_knn['bmi']

# %%
sns.kdeplot(df['age'],color='b')
sns.kdeplot(df['age_knn'],color='g')
plt.show()

# %%
df['age']=df_knn['age']

# %%
df.isnull().sum()
# Out:
# age                    0
# sex                    0
# weight                 0
# bmi                    0
# hereditary_diseases    0
# no_of_dependents       0
# smoker                 0
# city                   0
# bloodpressure          0
# diabetes               0
# regular_ex             0
# job_title              0
# claim                  0
# age_knn                0
# bmi_knn                0
# dtype: int64

# %%
df['bmi']=df_knn['bmi']

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         age     sex  weight   bmi hereditary_diseases  no_of_dependents  \
# 0      60.0    male      64  24.3           NoDisease                 1
# 1      49.0  female      75  22.6           NoDisease                 1
# 2      32.0  female      64  17.8            Epilepsy                 2
# 3      61.0  female      53  36.4           NoDisease                 1
# 4      19.0  female      50  20.6           NoDisease                 0
# ...     ...     ...     ...   ...                 ...               ...
# 14994  38.0  female      71  27.3           NoDisease                 1
# 14995  39.0    male      49  28.3           NoDisease                 1
# 14996  39.0    male      74  29.6           NoDisease                 4
# 14998  52.0    male      88  36.7           NoDisease                 0
# 14999  52.0    male      57  26.4           NoDisease                 3
#
#        smoker         city  bloodpressure  diabetes  regular_ex    job_title  \
# 0           0      NewYork             72         0           0        Actor
# 1           0       Boston             78         1           1     Engineer
# 2           1  Phildelphia             88         1           1  Academician
# 3           1    Pittsburg             72         1           0         Chef
# 4           0      Buffalo             82         1           0   HomeMakers
# ...       ...          ...            ...       ...         ...          ...
# 14994       0    Knoxville              0         1           0         Chef
# 14995       1     Florence             54         1           0    FilmMaker
# 14996       0        Miami             64         1           0      Student
# 14998       0   PanamaCity             70         1           0       Farmer
# 14999       0    Kingsport             72         1           0      Manager
#
#          claim  age_knn  bmi_knn
# 0      13112.6     60.0     24.3
# 1       9567.0     49.0     22.6
# 2      32734.2     32.0     17.8
# 3      48517.6     61.0     36.4
# 4       1731.7     19.0     20.6
# ...        ...      ...      ...
# 14994   6555.1     38.0     27.3
# 14995  21082.2     39.0     28.3
# 14996   7512.3     39.0     29.6
# 14998   9144.6     52.0     36.7
# 14999  25992.8     52.0     26.4
#
# [13904 rows x 15 columns]
